# %% [markdown]
# # Analisi vaccini
# ### Confronto Tra i vaccini Astrazeneca, Sputnik, Pfizer  in America ,Europa, Russia

# %%
from bsi_sentiment.twitter import search_tweets_sn
import pandas as pd
from datetime import datetime
import os
import glob
import qgrid

# %%
os.chdir(r'C:\Users\tranchinake\Desktop\DataScienceUniversity\LabBusinessAnalytic\Psicology\DS_LAB_PSYCOLOGY_2021')

# %% [markdown]
# #### Estrazione dati
#
# L'estrazione avviene tramite script scraping. Lo script prevede come input:
#
# 1) la parola da cercare (unsensitive)
#
# 2) la città di riferimento
#
# 3) il raggio in km del cerchio all'interno del quale cerchiamo i tweets
#
# 4) il numero totale di tweet
#
# 5) Periodo Di Estrazione

# %% [markdown]
# #### Funziona di Estrazione dati

# %%
def extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area):
    # prelevo i tweets
    tweets = search_tweets_sn(
      q=parolaCercata,
      since="2021-03-01",
      until="2021-03-31",
      near=citta,
      radius=raggio,
      lang="en",
      max_tweets=10000
    )
    
    if(len(tweets.tweets)!=0):
        # salvo il dataframe
        directory = './dataset/dataset_europa_inghilterra_08042021/'
        file= "tweet_"+"marzo"+"_"+parolaCercata+"_"+citta+"_"+raggio+".csv"
        tweets.to_csv(path= directory + file)

        #aggiungo la location
        df = pd.read_csv(directory+file)
        df['parola_cercata'] = parolaCercata
        df['location'] = location
        df['area'] = area
        df['citta'] = citta
        df['raggio'] = raggio
        df.to_csv(directory + file)
        print(file)
        return df
    return print("nessun tweets trovato con parolaCercata "+ parolaCercata)

# %%
## EU-Ovest
citta = "franckfurt"
raggio="100km"
location ='EU-Ovest'
area ='EU'

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)
# Out:
# Downloading tweets:  27%|███████████████████████████████████████▌                                                                                                            | 2673/10000 [00:27<01:15, 97.11it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2673/2673 [00:00<00:00, 78830.10it/s]

# %%
df
# Out:
#                       id                                          permalink  \
# 0    1366538552176218113  https://twitter.com/Daniell91509529/status/136...
# 1    1366538495557328896  https://twitter.com/DrMonicaMalta/status/13665...
# 2    1366538254829248513  https://twitter.com/nobodytweetnob/status/1366...
# 3    1366538230825246720  https://twitter.com/SyLicoNgaAko/status/136653...
# 4    1366538127335112705  https://twitter.com/thestarhalifax/status/1366...
# ..                   ...                                                ...
# 995  1366444164364181505  https://twitter.com/noname_8/status/1366444164...
# 996  1366444126003150852  https://twitter.com/CFNU/status/13664441260031...
# 997  1366444075004661761  https://twitter.com/SandraWeeden/status/136644...
# 998  1366444031123750912  https://twitter.com/CHATNewsToday/status/13664...
# 999  1366443950521860097  https://twitter.com/TheCullObsidian/status/136...
#
#             username                                               text  \
# 0    Daniell91509529  Just had my astra zeneca covid vaccine in all ...
# 1      DrMonicaMalta  A first dose of Oxford-AstraZeneca vaccine sub...
# 2     nobodytweetnob  AstraZeneca vaccine should not be used for sen...
# 3       SyLicoNgaAko  Pfizer, pfizer where art thou? AstraZeneca, as...
# 4     thestarhalifax  National panel advises against using AstraZene...
# ..               ...                                                ...
# 995         noname_8  UK Covid live: one dose of Pfizer or AstraZene...
# 996             CFNU  Health Canada announced it has approved the As...
# 997     SandraWeeden  Is it me? The data? 🤢🤷‍♀️\n\nA single shot of ...
# 998    CHATNewsToday  Feds hoping for AstraZeneca shots this week as...
# 999  TheCullObsidian  UK Covid live: one dose of Pfizer or AstraZene...
#
#            date parola_cercata  location area       citta raggio
# 0    2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 1    2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 2    2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 3    2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 4    2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# ..          ...            ...       ...  ...         ...    ...
# 995  2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 996  2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 997  2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 998  2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
# 999  2021-03-01    AstraZeneca  EU-Ovest   EU  franckfurt  100km
#
# [1000 rows x 10 columns]

# %% [markdown]
# #### Estrazione dati America

# %% [markdown]
# #### Indianapolis

# %%
start = datetime.today()

# %%
## EU-Ovest
citta = "Lisbona"
raggio="100km"
location ='EU-Ovest'
area ='EU'

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

## EU-Ovest
citta = "Madrid"
raggio="300km"
location ='EU-Ovest'
area ='EU'

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

################## EU-central
location ='EU-CENTRAL'
area ='EU'

citta = "Roma"
raggio="400km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

citta = "franckfurt"
raggio="300km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

citta = "Praga"
raggio="100km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


################# EU-est
location ='EU-est'
area ='EU'

citta = "varsavia"
raggio="300km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


## EU-est
citta = "Bucarest"
raggio="700km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

############### EU-Nord
location ='EU-Nord'
area ='EU'


citta = "Oslo"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

#################
citta = "Stoccolma"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


##################
citta = "Amburg"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

##################
citta = "Helsinki"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)



##### Londra
location ='GB-SUD'
area ='GB'
citta = "London"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


##### Londra
location ='GB-Nord'
area ='GB'
citta = "Edimburg"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


##### Londra
location ='GB-Center'
area ='GB'
citta = "Manchester"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)
# Out:
# Downloading tweets:   0%|                                                                                                                                                    | 6/100000 [00:00<4:18:12,  6.45it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<?, ?it/s]
# Downloading tweets:   0%|                                                                                                                                                     | 49/100000 [00:01<46:44, 35.65it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 49/49 [00:00<00:00, 49155.92it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 21/100000 [00:02<3:15:45,  8.51it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 21/21 [00:00<?, ?it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 138/100000 [00:04<56:56, 29.23it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 138/138 [00:00<00:00, 69203.01it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 34/100000 [00:04<3:16:55,  8.46it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 34/34 [00:00<00:00, 34051.18it/s]
# Downloading tweets:   0%|▏                                                                                                                                                 | 114/100000 [00:05<1:16:45, 21.69it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 114/114 [00:00<00:00, 56306.01it/s]
# Downloading tweets: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [19:41<00:00, 84.66it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:02<00:00, 42374.99it/s]
# Downloading tweets: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [23:34<00:00, 70.72it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:05<00:00, 19838.80it/s]
# Downloading tweets:   0%|                                                                                                                                                    | 6/100000 [00:01<9:12:51,  3.01it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 3006.67it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 35/100000 [00:01<1:19:21, 20.99it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 35/35 [00:00<00:00, 5850.50it/s]
# Downloading tweets:   0%|                                                                                                                                                              | 0/100000 [00:03<?, ?it/s]
# Downloading tweets:   0%|                                                                                                                                                              | 0/100000 [00:00<?, ?it/s]
# nessun tweets trovato con parolaCercata AstraZeneca
# Downloading tweets:   0%|                                                                                                                                                   | 33/100000 [00:06<5:20:01,  5.21it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 33/33 [00:00<00:00, 4792.00it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 26/100000 [00:02<3:08:41,  8.83it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 26/26 [00:00<00:00, 14764.68it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 14/100000 [00:02<5:50:23,  4.76it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 6773.59it/s]
# Downloading tweets:   0%|                                                                                                                                                    | 8/100000 [00:01<5:14:52,  5.29it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 3189.89it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 37/100000 [00:01<1:16:35, 21.75it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37/37 [00:00<00:00, 7429.23it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 14/100000 [00:01<3:24:11,  8.16it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 14/14 [00:00<00:00, 4421.71it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 119/100000 [00:03<42:39, 39.02it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 119/119 [00:00<00:00, 13267.47it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 100/100000 [00:02<44:30, 37.41it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 8865.95it/s]
# Downloading tweets:   0%|                                                                                                                                                              | 0/100000 [00:00<?, ?it/s]
# Downloading tweets:   0%|                                                                                                                                                              | 0/100000 [00:00<?, ?it/s]
# nessun tweets trovato con parolaCercata EU
# Downloading tweets:   0%|                                                                                                                                                   | 11/100000 [00:02<5:08:13,  5.41it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 5495.16it/s]
# Downloading tweets:   0%|                                                                                                                                                   | 23/100000 [00:01<1:42:55, 16.19it/s]
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 5169.00it/s]
# Downloading tweets:   1%|▊                                                                                                                                                   | 586/100000 [00:10<28:37, 57.88it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 586/586 [00:00<00:00, 12954.66it/s]
# Downloading tweets:   1%|██                                                                                                                                                 | 1371/100000 [00:20<24:48, 66.26it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1371/1371 [00:00<00:00, 10257.60it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 113/100000 [00:03<48:03, 34.64it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 113/113 [00:00<00:00, 8096.70it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 129/100000 [00:03<40:09, 41.44it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 129/129 [00:00<00:00, 7715.95it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 153/100000 [00:02<31:40, 52.54it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 153/153 [00:00<00:00, 18237.14it/s]
# Downloading tweets:   0%|▏                                                                                                                                                   | 163/100000 [00:02<28:26, 58.50it/s]
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 163/163 [00:00<00:00, 9112.58it/s]

# %%
##### Londra
location ='GB-SUD'
area ='GB'
citta = "London"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


##### Londra
location ='GB-Nord'
area ='GB'
citta = "Edimburg"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)


##### Londra
location ='GB-Center'
area ='GB'
citta = "Manchester"
raggio="200km"

parolaCercata="AstraZeneca"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)

parolaCercata="EU"
df = extractDataAndSaveInCsv(citta,parolaCercata,raggio,location,area)
# Out:
# Downloading tweets:   4%|█████▍                                                                                                                                               | 361/10000 [00:07<03:30, 45.78it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 361/361 [00:00<00:00, 51712.56it/s]
# Downloading tweets:   7%|██████████▌                                                                                                                                          | 708/10000 [00:13<03:03, 50.62it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 708/708 [00:00<00:00, 78891.83it/s]
# Downloading tweets:   0%|▋                                                                                                                                                     | 48/10000 [00:02<09:13, 17.97it/s]
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 23213.03it/s]
# Downloading tweets:   1%|█▌                                                                                                                                                   | 103/10000 [00:02<04:06, 40.09it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 103/103 [00:00<00:00, 25810.33it/s]
# Downloading tweets:   1%|██                                                                                                                                                   | 139/10000 [00:03<04:29, 36.59it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 139/139 [00:00<00:00, 34835.58it/s]
# Downloading tweets:   1%|█▋                                                                                                                                                   | 114/10000 [00:02<03:29, 47.29it/s]
# Writing tweets    : 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 114/114 [00:00<00:00, 28568.48it/s]

# %%
finish = datetime.today()

# %%
finish = datetime.today()
deltaTime = finish-start
minuti = deltaTime.total_seconds()/60
minuti
# Out:
# 45.18181251666667

# %%
os.chdir(r'C:\Users\tranchinake\Desktop\DataScienceUniversity\LabBusinessAnalytic\Psicology\DS_LAB_PSYCOLOGY_2021')
os.chdir("./dataset/dataset_europa_inghilterra_08042021/")
extension = 'csv' 
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['tweet_marzo_AstraZeneca_Edimburg_200km.csv',
#  'tweet_marzo_AstraZeneca_franckfurt_1000km.csv',
#  'tweet_marzo_AstraZeneca_London_200km.csv',
#  'tweet_marzo_AstraZeneca_Manchester_200km.csv',
#  'tweet_marzo_EU_Edimburg_200km.csv',
#  'tweet_marzo_EU_franckfurt_1000km.csv',
#  'tweet_marzo_EU_London_200km.csv',
#  'tweet_marzo_EU_Manchester_200km.csv']

# %%
df = pd.concat([pd.read_csv( f) for f in all_filenames ])
df
# Out:
#      Unnamed: 0                   id  \
# 0             0  1376531802836377600
# 1             1  1376124682848600064
# 2             2  1376105970594689024
# 3             3  1375875499717750790
# 4             4  1375861727053680644
# ..          ...                  ...
# 109         109  1367773693854711812
# 110         110  1367728901854797826
# 111         111  1367401336527069185
# 112         112  1366902328880693250
# 113         113  1366832911031369744
#
#                                              permalink         username  \
# 0    https://twitter.com/Jack1872Royal/status/13765...    Jack1872Royal
# 1    https://twitter.com/nigelairey/status/13761246...       nigelairey
# 2    https://twitter.com/HesterMcQueen/status/13761...    HesterMcQueen
# 3    https://twitter.com/nufcscott1968/status/13758...    nufcscott1968
# 4    https://twitter.com/janewilson_1812/status/137...  janewilson_1812
# ..                                                 ...              ...
# 109  https://twitter.com/BeverlyMacker/status/13677...    BeverlyMacker
# 110  https://twitter.com/alictaylor1/status/1367728...      alictaylor1
# 111  https://twitter.com/DonaldJudge/status/1367401...      DonaldJudge
# 112  https://twitter.com/WCONNOLLY2512/status/13669...    WCONNOLLY2512
# 113  https://twitter.com/Stevethsoundman/status/136...  Stevethsoundman
#
#                                                   text        date  \
# 0    Hi Gail, hope your better if you get the Oxfor...  2021-03-29
# 1    Well that’s the first Covid-19 vaccination, do...  2021-03-28
# 2    Safe, stable, sold at cost: AstraZeneca’s vacc...  2021-03-28
# 3    That's me jabbed, AstraZeneca Boys are in town...  2021-03-27
# 4    Feck knows what’s in that AstraZeneca... but I...  2021-03-27
# ..                                                 ...         ...
# 109  Hey @BorisJohnson you’ve  forgotten the spare ...  2021-03-05
# 110  Environment secretary : Stop UK farmers using ...  2021-03-05
# 111  Is this the UK that's outpaced much of the EU ...  2021-03-04
# 112  More EU countries are parting ways from disast...  2021-03-03
# 113  Remember the first vote of No Confidence in Th...  2021-03-02
#
#     parola_cercata   location area       citta raggio
# 0      AstraZeneca    GB-Nord   GB    Edimburg  200km
# 1      AstraZeneca    GB-Nord   GB    Edimburg  200km
# 2      AstraZeneca    GB-Nord   GB    Edimburg  200km
# 3      AstraZeneca    GB-Nord   GB    Edimburg  200km
# 4      AstraZeneca    GB-Nord   GB    Edimburg  200km
# ..             ...        ...  ...         ...    ...
# 109             EU  GB-Center   GB  Manchester  200km
# 110             EU  GB-Center   GB  Manchester  200km
# 111             EU  GB-Center   GB  Manchester  200km
# 112             EU  GB-Center   GB  Manchester  200km
# 113             EU  GB-Center   GB  Manchester  200km
#
# [937898 rows x 11 columns]

# %%
df['location'].value_counts()
# Out:
# EU-CENTRAL    936425
# GB-SUD          1069
# GB-Center        253
# GB-Nord          151
# Name: location, dtype: int64

# %%
df['parola_cercata'].value_counts()
# Out:
# EU             725648
# AstraZeneca    212250
# Name: parola_cercata, dtype: int64

# %%
df[df['location'].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, permalink, username, text, date, parola_cercata, location, area, citta, raggio]
# Index: []

# %%
df[df['permalink'] == "https://twitter.com/teixeirahambro/status/1366177557738119169"]
# Out:
#         Unnamed: 0                   id  \
# 724680      724680  1366177557738119169
#
#                                                 permalink        username  \
# 724680  https://twitter.com/teixeirahambro/status/1366...  teixeirahambro
#
#                                                      text        date  \
# 724680  What is @Priti Patel doing about it, after agr...  2021-03-01
#
#        parola_cercata    location area       citta  raggio
# 724680             EU  EU-CENTRAL   EU  franckfurt  1000km

# %%
duplicati = df[df.duplicated(subset=['id'])==True].sort_values('id')
len(duplicati)
# Out:
# 23136

# %%
qgrid.show_grid(duplicati,grid_options = {'forceFitColumns':False,'syncColumnCellResize': False,'highlightSelectedCell': True,'rowHeight': 25},
                show_toolbar=True,
               column_options ={ 'resizable': True,})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': False, 'forceFitColumns': False, 'def…

# %%
df = df[df.duplicated(subset=['permalink'])==False]

# %%
df = df.drop(['Unnamed: 0'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-b9d9ec825c54> in <module>
# ----> 1 df = df.drop(['Unnamed: 0'], axis=1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4310             level=level,
#    4311             inplace=inplace,
# -> 4312             errors=errors,
#    4313         )
#    4314
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %%
df.to_csv("all_astrazeneca_eu_in_eu_gb_10042021.csv", index=False)

# %%
df = df.read_csv("all_astrazeneca_eu_in_eu_gb_10042021.csv")

# %%
len(df['text'].unique())
# Out:
# 186242
