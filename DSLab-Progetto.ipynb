# %% [markdown]
# # Analisi vaccini
# ### Confronto Tra i vaccini Astrazeneca, Sputnik, Pfizer  in America ,Europa, Russia

# %%
os.chdir(r'C:\Users\tranchinake\Desktop\DataScienceUniversity\LabBusinessAnalytic\Psicology\DS_LAB_PSYCOLOGY_2021')

# %%
from bsi_sentiment.twitter import search_tweets_sn
import pandas as pd
from datetime import datetime
import os
import glob

# %% [markdown]
# #### Estrazione dati
#
# L'estrazione avviene tramite script scraping. Lo script prevede come input:
#
# 1) la parola da cercare (unsensitive)
#
# 2) la città di riferimento
#
# 3) il raggio in km del cerchio all'interno del quale cerchiamo i tweets
#
# 4) il numero totale di tweet
#
# 5) Periodo Di Estrazione
#
#
# ### Abbiamo scelto 3 macro regioni
#
# America: SaltLake City e Indianapolis con raggio 1100 km
#
# Europa: francoforte 760 km + Are (città in finlandia) con raggio 800km
#
# Russia : Moscow raggio 700 km

# %% [markdown]
# #### Funziona di Estrazione dati

# %%
def extractDataAndSaveInCsv(citta, vaccino,raggio,location):
    # prelevo i tweets
    tweets = search_tweets_sn(
      q=vaccino,
      since="2021-03-01",
      until="2021-03-31",
      near=citta,
      radius=raggio,
      lang="en",
      max_tweets=100000
    )
    
    if(len(tweets.tweets)!=0):
        # salvo il dataframe
        directory = './dataset/dataset_tweets/'
        file= "tweet_"+"marzo"+vaccino+"_"+citta+"_"+raggio+".csv"
        tweets.to_csv(path= directory + file)

        #aggiungo la location
        df = pd.read_csv(directory+file)
        df['vaccino'] = vaccino
        df['location'] = location
        df.to_csv(directory + file)
        return df
    return print("nessun tweets trovato con vaccino "+ vaccino)

# %% [markdown]
# #### Estrazione dati America

# %% [markdown]
# #### Indianapolis

# %%
start = datetime.today()

# %%
citta = "Indianapolis"
raggio="1200km"
location ='America'

# %%
## Astrazeneca

vaccino="AstraZeneca"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Sputnik

vaccino="Sputnik"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Pfizer 
vaccino="Pfizer"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)
# Out:
# ...
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9628/9628 [00:00<00:00, 109707.14it/s]
#                        id                                          permalink  \
# 0     1377047955199426560  https://twitter.com/tonyheyl/status/1377047955...
# 1     1377047667612606465  https://twitter.com/BuzzJackson/status/1377047...
# 2     1377047618258341892  https://twitter.com/NinjaHamstr/status/1377047...
# 3     1377047536037474305  https://twitter.com/nyc_vaccine/status/1377047...
# 4     1377047334362750978  https://twitter.com/chachina/status/1377047334...
# ...                   ...                                                ...
# 9623  1366196692098367491  https://twitter.com/chrisdemartine/status/1366...
# 9624  1366195751777353730  https://twitter.com/ronca_kimberley/status/136...
# ...

# %% [markdown]
# #### Salt Lake

# %%
citta = "Salt Lake"
raggio="1200km"
location ='America'

# %%
## Astrazeneca

vaccino="AstraZeneca"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Sputnik

vaccino="Sputnik"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Pfizer 
vaccino="Pfizer"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)
# Out:
# ...
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:02<00:00, 34610.66it/s]
#                         id                                          permalink  \
# 0      1377047955199426560  https://twitter.com/tonyheyl/status/1377047955...
# 1      1377047772382310403  https://twitter.com/StevenDBT/status/137704777...
# 2      1377047667612606465  https://twitter.com/BuzzJackson/status/1377047...
# 3      1377047618925236226  https://twitter.com/JasperSzwarc/status/137704...
# 4      1377047618258341892  https://twitter.com/NinjaHamstr/status/1377047...
# ...                    ...                                                ...
# 99995  1368706213551087618  https://twitter.com/pepperonify/status/1368706...
# 99996  1368706132273889280  https://twitter.com/Sioloboy/status/1368706132...
# ...

# %% [markdown]
# #### Estrazione dati Europa

# %% [markdown]
# #### Francoforte

# %%
citta = "Frankfurt"
raggio="760km"
location ='Europa'

# %%
## Astrazeneca

vaccino="AstraZeneca"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Sputnik

vaccino="Sputnik"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Pfizer 
vaccino="Pfizer"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)
# Out:
# ...
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 36/36 [00:00<00:00, 9023.24it/s]
#                      id                                          permalink  \
# 0   1377027818144608264  https://twitter.com/UrsulaZlamal/status/137702...
# 1   1377024352651214852  https://twitter.com/14wombat1/status/137702435...
# 2   1376993396137463808  https://twitter.com/JComm_NewsFeeds/status/137...
# 3   1376951668479303683  https://twitter.com/swisscryptocat/status/1376...
# 4   1376949890631208962  https://twitter.com/mehabecapital/status/13769...
# 5   1376946730034458637  https://twitter.com/SchalkeMerica/status/13769...
# 6   1376934230970793994  https://twitter.com/TepiZep/status/13769342309...
# 7   1376920055724843017  https://twitter.com/d0wnw4rdsp1ral/status/1376...
# 8   1376881202427215881  https://twitter.com/AzurDiver/status/137688120...
# ...

# %% [markdown]
# #### Are

# %%
citta = "Are"
raggio="800km"
location ='Europa'

# %%
## Astrazeneca

vaccino="AstraZeneca"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Sputnik

vaccino="Sputnik"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Pfizer 
vaccino="Pfizer"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)
# Out:
# ...
# Writing tweets    : 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 71/71 [00:00<00:00, 17610.62it/s]
# ...
# nessun tweets trovato con vaccino Sputnik
# ...
# Writing tweets    : 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 7485.37it/s]
#                      id                                          permalink  \
# 0   1376968122989678593  https://twitter.com/spcysndwchnpckl/status/137...
# 1   1376895194180640772  https://twitter.com/javyvera65/status/13768951...
# 2   1376884446582870019  https://twitter.com/javyvera65/status/13768844...
# 3   1376730299682357250  https://twitter.com/dianneclynne/status/137673...
# 4   1376644597737271297  https://twitter.com/NP4Charley/status/13766445...
# ...

# %% [markdown]
# #### Estrazione dati Russia

# %%
citta = "Moscow"
raggio="700km"
location ='Russia'

# %%
## Astrazeneca

vaccino="AstraZeneca"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Sputnik

vaccino="Sputnik"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)

## Pfizer 
vaccino="Pfizer"
extractDataAndSaveInCsv(citta,vaccino , raggio , location)
# Out:
# ...
# Writing tweets    : 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 1001.74it/s]
#                     id                                          permalink  \
# 0  1376565697413795842  https://twitter.com/sputnikvaccine/status/1376...
#
#          username                                               text  \
# 0  sputnikvaccine  Is Sputnik V now the most efficient vaccine in...
#
#          date vaccino location
# 0  2021-03-29  Pfizer   Russia

# %%
finish = datetime.today()

# %%
deltaTime = finish-start
minuti = deltaTime.total_seconds()/60
minuti
# Out:
# 50.66383785

# %%
# os.chdir("./dataset/dataset_tweets/")
extension = 'csv' 
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
all_filenames
# Out:
# ['tweet_marzoAstraZeneca_Are_800km.csv',
#  'tweet_marzoAstraZeneca_Frankfurt_760km.csv',
#  'tweet_marzoAstraZeneca_Indianapolis_1200km.csv',
#  'tweet_marzoAstraZeneca_Moscow_700km.csv',
#  'tweet_marzoAstraZeneca_Salt Lake_1200km.csv',
#  'tweet_marzoPfizer_Are_800km.csv',
#  'tweet_marzoPfizer_Frankfurt_760km.csv',
#  'tweet_marzoPfizer_Indianapolis_1200km.csv',
#  'tweet_marzoPfizer_Moscow_700km.csv',
#  'tweet_marzoPfizer_Salt Lake_1200km.csv',
#  'tweet_marzoSputnik_Frankfurt_760km.csv',
#  'tweet_marzoSputnik_Indianapolis_1100km.csv',
#  'tweet_marzoSputnik_Indianapolis_1200km.csv',
#  'tweet_marzoSputnik_Moscow_700km.csv',
#  'tweet_marzoSputnik_Salt Lake_1200km.csv']

# %%
df = pd.concat([pd.read_csv( f) for f in all_filenames ])
df
# Out:
#        Unnamed: 0                   id  \
# 0             0.0  1377047591498645509
# 1             1.0  1377046528016060420
# 2             2.0  1377046369081376768
# 3             3.0  1377046366971695107
# 4             4.0  1377044075296227333
# ...           ...                  ...
# 17931     17931.0  1366188861471285251
# 17932     17932.0  1366187998375723014
# 17933     17933.0  1366184432034488324
# 17934     17934.0  1366181583338766341
# 17935     17935.0  1366176595841605638
#
#                                                permalink         username  \
# 0      https://twitter.com/VivienneArmst15/status/137...  VivienneArmst15
# 1      https://twitter.com/opa1420/status/13770465280...          opa1420
# 2      https://twitter.com/TR76News/status/1377046369...         TR76News
# 3      https://twitter.com/TR76News/status/1377046366...         TR76News
# 4      https://twitter.com/pcharlesjr/status/13770440...       pcharlesjr
# ...

# %%
df['location'].value_counts()
# Out:
# America    232251
# Europa        354
# Russia         50
# Name: location, dtype: int64

# %%
df
# Out:
#        Unnamed: 0                   id  \
# 0               0  1377047591498645509
# 1               1  1377046528016060420
# 2               2  1377046369081376768
# 3               3  1377046366971695107
# 4               4  1377044075296227333
# ...           ...                  ...
# 17931       17931  1366188861471285251
# 17932       17932  1366187998375723014
# 17933       17933  1366184432034488324
# 17934       17934  1366181583338766341
# 17935       17935  1366176595841605638
#
#                                                permalink         username  \
# 0      https://twitter.com/VivienneArmst15/status/137...  VivienneArmst15
# 1      https://twitter.com/opa1420/status/13770465280...          opa1420
# 2      https://twitter.com/TR76News/status/1377046369...         TR76News
# 3      https://twitter.com/TR76News/status/1377046366...         TR76News
# 4      https://twitter.com/pcharlesjr/status/13770440...       pcharlesjr
# ...

# %%
df[df['location'].isna()]
# Out:
#      Unnamed: 0                   id  \
# 0           NaN  1377045498486349824
# 1           NaN  1377033812371202058
# 2           NaN  1377028776958169091
# 3           NaN  1377028537425612805
# 4           NaN  1377022877615198214
# ..          ...                  ...
# 309         NaN  1367492337132306439
# 310         NaN  1367196140253364229
# 311         NaN  1366852948672868356
# 312         NaN  1366757620602851329
# 313         NaN  1366521692013518851
#
#                                              permalink         username  \
# 0    https://twitter.com/TartWrangler/status/137704...     TartWrangler
# 1    https://twitter.com/flugennock/status/13770338...       flugennock
# 2    https://twitter.com/ladykrick2/status/13770287...       ladykrick2
# 3    https://twitter.com/terencebjohnson/status/137...  terencebjohnson
# 4    https://twitter.com/jtwigg9/status/13770228776...          jtwigg9
# ..                                                 ...              ...
# ...
